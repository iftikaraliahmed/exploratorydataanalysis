# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

path = r"C:\Users\Administrator\Documents"
os.chdir(path)
os.listdir(path)
# Out:
# ['.RData',
#  '.Rhistory',
#  'Amazon',
#  'Book1.xlsx',
#  'Book1z.xlsx',
#  'Book2.xlsx',
#  'Book3.xlsx',
#  'Call Centre Analysis- Data set',
#  'Call Centre Analysis- Data set.rar',
#  'Cars.xlsx',
#  'Chapter 3 - R Overview.pdf',
#  'chisqtab.pdf',
#  'covariance, correlation sums.xlsx',
#  'Custom Office Templates',
#  'daily-minimum-temperatures.xlsx',
#  'Data and time.xlsx',
#  'day1.txt.R',
#  'day2.1.R.RData',
#  'day2.R',
#  'day2.txt',
#  'day3.txt',
#  'desktop.ini',
#  'Drinks.xlsx',
#  'EDA',
#  'Fin_Exercises 1.docx',
#  'freq_dist_data_out.csv',
#  'FTable.pdf',
#  'homicide.csv',
#  'Hospitality_Management_Paper_Stats.pdf',
#  'HR Analytics.csv',
#  'HR Analytics.docx',
#  'Internship Survey.xls',
#  'IPL Data',
#  'Kolmogorv-Smirnov Test.pdf',
#  'kruskalwallish.pdf',
#  'My Data Sources',
#  'My Music',
#  'My Pictures',
#  'My Videos',
#  'narendramodi_tweets.xlsx',
#  'NumPy & Pandas_ detailed syllabi.docx',
#  'odi-batting.csv',
#  'penalty_data.csv',
# ...

# %%
hr=pd.read_csv('HR Analytics.csv',low_memory=False)

# %%
list(hr)
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'JobInvolvement',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'TotalWorkingYears',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
#Q1 What proportion of out staff are leaving
staff_no=len(hr[hr['Attrition']==1])
proportion=staff_no/(len(hr))*100
proportion
# Out:
# 16.122448979591837

# %%
hr2 = hr.groupby(['Gender','Department'])['EmployeeNumber'].count().reset_index()
hr2.sort_values(by='EmployeeNumber',ascending=False).head()
# Out:
#    Gender              Department  EmployeeNumber
# 4    Male  Research & Development             582
# 1  Female  Research & Development             379
# 5    Male                   Sales             257
# 2  Female                   Sales             189
# 3    Male         Human Resources              43

# %%
#Q2 What role does gender and age play in this workplace
hr2 = hr.groupby(['Gender','Age','Department'])['Attrition'].count().reset_index()
hr2.sort_values(by='Age',ascending=False)
# Out:
#      Gender  Age              Department  Attrition
# 204    Male   60                   Sales          2
# 95   Female   60  Research & Development          1
# 96   Female   60                   Sales          1
# 203    Male   60  Research & Development          1
# 202    Male   59                   Sales          1
# 200    Male   59         Human Resources          1
# 201    Male   59  Research & Development          2
# 94   Female   59                   Sales          3
# 93   Female   59  Research & Development          2
# 92   Female   59         Human Resources          1
# 90   Female   58  Research & Development          5
# 198    Male   58  Research & Development          6
# 91   Female   58                   Sales          1
# 199    Male   58                   Sales          2
# 196    Male   57  Research & Development          3
# 197    Male   57                   Sales          1
# 194    Male   56         Human Resources          1
# ...

# %%
#Q3
hr3=hr.groupby(['Department','MonthlyIncome','TotalWorkingYears'])['Attrition'].count().reset_index()
hr3.sort_values(by='Attrition',ascending=False).head()
# Out:
#                   Department  MonthlyIncome  TotalWorkingYears  Attrition
# 287   Research & Development           2693                  1          2
# 1227                   Sales           5561                  6          2
# 1163                   Sales           4779                  8          2
# 497   Research & Development           4025                 10          2
# 1031                   Sales           2033                  1          2

# %%
list(hr)
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'JobInvolvement',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'TotalWorkingYears',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

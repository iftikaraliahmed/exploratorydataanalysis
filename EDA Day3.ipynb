# %%
#Importing data
import os
import pandas as pd

path = r"C:\Users\Administrator\Documents\IPL Data"

os.chdir(path)

os.listdir(path)

ball = pd.read_excel("Ball_by_Ball.xlsx")

match = pd.read_excel("Match.xlsx")

player = pd.read_excel("Player.xlsx")

player_match = pd.read_excel('Player_Match.xlsx')

season = pd.read_excel('Season.xlsx')

team = pd.read_excel('Team.xlsx')

# %%
#Decision making after winning the toss

# %%
match.head()
# Out:
#    Match_Id Match_Date  Team_Name_Id  Opponent_Team_Id  Season_Id  \
# 0    335987 2008-04-18             2                 1          1
# 1    335988 2008-04-19             4                 3          1
# 2    335989 2008-04-19             6                 5          1
# 3    335990 2008-04-20             7                 2          1
# 4    335991 2008-04-20             1                 8          1
#
#                                    Venue_Name  Toss_Winner_Id Toss_Decision  \
# 0                       M Chinnaswamy Stadium               2         field
# 1  Punjab Cricket Association Stadium, Mohali               3           bat
# 2                            Feroz Shah Kotla               5           bat
# 3                            Wankhede Stadium               7           bat
# 4                                Eden Gardens               8           bat
#
#    IS_Superover  IS_Result  Is_DuckWorthLewis    Win_Type  Won_By  \
# ...

# %%
Toss = match.groupby(['Toss_Decision']).size().reset_index()
Toss = Toss.rename(columns = {0 : 'No of matches'})
Toss
# Out:
#   Toss_Decision  No of matches
# 0           bat            262
# 1         field            315

# %%
#changing column name
Toss = Toss.rename(columns = {0 : 'No of matches'})
Toss

# %%
#Presenting the same with pie chart

from matplotlib import pyplot as plt

plt.pie(Toss['No of matches'], labels=Toss['Toss_Decision'], autopct="%.2f%%")

plt.show()

# %%
plt.pie(Toss['No of matches'], labels=Toss['Toss_Decision'], autopct="%.2f%%",
       labeldistance=0.0, radius=1.5)

plt.show()

# %%
#Exploring the function of explode, pctdistance, labeldistance

ex = {0,0,0.2}
plt.pie(Toss['No of matches'], labels=Toss['Toss_Decision'], autopct="%.2f%%",
       explode=ex)

plt.show()

# %%
#PS: Country wise contribution in runs (apart from india)
Country = player.groupby(['Player_Id','Player_Name','Country']).sum().reset_index()

Country.head()
# Out:
#    Player_Id      Player_Name      Country  Is_Umpire  Unnamed: 7
# 0          1       SC Ganguly        India          0         0.0
# 1          2      BB McCullum  New Zealand          0         0.0
# 2          3       RT Ponting    Australia          0         0.0
# 3          4        DJ Hussey    Australia          0         0.0
# 4          5  Mohammad Hafeez     Pakistan          0         0.0

# %%
Player_region = Country[Country['Country']!= 'India']
Player_region
# Out:
#      Player_Id        Player_Name       Country  Is_Umpire  Unnamed: 7
# 1            2        BB McCullum   New Zealand          0         0.0
# 2            3         RT Ponting     Australia          0         0.0
# 3            4          DJ Hussey     Australia          0         0.0
# 4            5    Mohammad Hafeez      Pakistan          0         0.0
# 8            9          JH Kallis  South Africa          0         0.0
# 9           10           CL White     Australia          0         0.0
# 10          11         MV Boucher  South Africa          0         0.0
# 12          13          AA Noffke     Australia          0         0.0
# 17          18          ML Hayden     Australia          0         0.0
# 18          19         MEK Hussey     Australia          0         0.0
# 21          22           JDP Oram   New Zealand          0         0.0
# 24          25           JR Hopes     Australia          0         0.0
# ...

# %%
Batsman_Scored=ball.groupby('Striker_Id')['Batsman_Scored'].sum().reset_index()
Batsman_Scored
# Out:
#      Striker_Id  Batsman_Scored
# 0             1            1349
# 1             2            2435
# 2             3              91
# 3             4            1322
# 4             5              64
# 5             6            2170
# 6             7             130
# 7             8            4105
# 8             9            2427
# 9            10             971
# 10           11             394
# 11           12              76
# 12           13               9
# 13           14             332
# 14           15             113
# 15           16               6
# 16           17            1927
# 17           18            1107
# 18           19            1977
# 19           20            3270
# 20           21            4106
# 21           22             106
# 22           23            1441
# 23           24             218
# 24           25             417
# 25           26            1687
# 26           27            2339
# 27           28             237
# ...

# %%
ball.head()
# Out:
#    Match_Id  Season_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  \
# 0    335987          1           1        1        1                1
# 1    335987          1           1        1        2                1
# 2    335987          1           1        1        3                1
# 3    335987          1           1        1        4                1
# 4    335987          1           1        1        5                1
#
#    Team_Bowling_Id  Striker_Id  Striker_Batting_Position  Non_Striker_Id  \
# 0                2           1                         1               2
# 1                2           2                         2               1
# 2                2           2                         2               1
# 3                2           2                         2               1
# 4                2           2                         2               1
#
#    Bowler_Id  Batsman_Scored Extra_Type Extra_Runs Player_dissimal_Id  \
# ...

# %%
Player_score=pd.merge(Batsman_Scored,Player_region,left_on='Striker_Id',right_on='Player_Id')
Player_score=Player_score.groupby('Country')['Batsman_Scored'].sum().reset_index()
Player_score
# Out:
#         Country  Batsman_Scored
# 0     Australia           26447
# 1    Bangladesh             503
# 2       England            2943
# 3   Netherlands             326
# 4   New Zealand            5745
# 5      Pakistan            1107
# 6  South Africa           17539
# 7     Sri Lanka            6853
# 8   West Indies           11204
# 9     Zimbabwea              31

# %%
plt.pie(Player_score['Batsman_Scored'],labels=Player_score['Country'],autopct='%.2f%%',labeldistance=0.5,radius=1.5)

plt.show()

# %%
#Grouping the runs on country

Forg_country_wise = Player_region.groupby(['Country'])['Batsman_Scored'].sum().reset_index()

Forg_country_wise

# %%
#Creating Donut Chart

#Creating a small circle

plt.pie(Forg_country_wise['Batsman_Scored'],
        labels=Forg_country_wise['Country'], autopct="%.2f%%", radius=2, pctdistance=.75)

centre_circle = plt.Circle((0,0),0.8,fc='white')

fig = plt.gcf()

fig.gca().add_artist(centre_circle)

plot.show()

# %%
car = pd.read_excel('C:/Users/Administrator/Documents/Cars.xlsx')
car.head()
# Out:
#   manufacturer model  displ  year  cyl       trans  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   16   26  p  compact

# %%
len(car)
# Out:
# 234

# %%
#Lets check the city mileage distribution interms of frequency

plt.hist(car['cty'], width=2)

plt.xlabel('City Mileage bins')

plt.ylabel('No of Cars')
plt.show()

# %%
import seaborn as sns
sns.distplot(car['cty'])

#sns.show()

# %%
car.skew()
# Out:
# displ    0.444316
# year     0.000000
# cyl      0.113800
# cty      0.796561
# hwy      0.369236
# dtype: float64

# %%
import numpy as np
car['cty_sqrt'] = np.sqrt(car['cty'])    #car.head()
car.skew()
# Out:
# displ       0.444316
# year        0.000000
# cyl         0.113800
# cty         0.796561
# hwy         0.369236
# cty_sqrt    0.359486
# dtype: float64

# %%
car['cty_sqrt'] = np.sqrt(car['cty'])
car.head()
sns.distplot(car['cty'])

# %%
#Matplotlib subplot

fig = plt.figure()

plt.subplot(1,2,1)

plt.hist(car['cty'])
plt.xlabel('City Mileage')
plt.ylabel('No of cars')

plt.subplot(1,2,2)

plt.hist(car['hwy'])
plt.xlabel('Highway mileage')

plt.show()

# %%
g = sns.FacetGrid(car, col = "class")  #creating grids fot the dis

g = g.map(plt.hist,"cty")

# %%
car['cty'].describe()
# Out:
# count    234.000000
# mean      16.858974
# std        4.255946
# min        9.000000
# 25%       14.000000
# 50%       17.000000
# 75%       19.000000
# max       35.000000
# Name: cty, dtype: float64

# %%
np.quantile(car['cty'])

# %%
UL = 19 + 1.5*IQR

LL = 14 - 1.5*IQR
car['Status']

# %%
car.boxplot(column='cty')      #plt.boxplot(car['cty'])

# %%
car.boxplot(column='hwy')

# %%
#how many unique class or cars are there                      #Continuation Day4 EDA 

car['class'].unique()
# Out:
# array(['compact', 'midsize', 'suv', '2seater', 'minivan', 'pickup',
#        'subcompact'], dtype=object)

# %%
#Creating one box plot for each class

#import seaborn as sns
plt.rcParams['figure.figsize'] = [20,8]
sns.boxplot(data=car, x = 'class',y ='cty')

# %%
plt.rcParams['figure.figsize'] = [20,8]
sns.boxplot(data = car, x = 'manufacturer', y = 'cty')

# %%
#Bivariant Analysis
plt.rcParams['figure.figsize']=[8,6]
plt.scatter(car['cty'],car['hwy'])
plt.xlabel('City Milage')
plt.ylabel('Highway Milage')
plt.show()

# %%
len(car[car.cty]<10)

# %%
#Correlation between city milage and highway

car_new = car[['cty','hwy']]
car_new.corr()
# Out:
#           cty       hwy
# cty  1.000000  0.955916
# hwy  0.955916  1.000000

# %%
car_new1 = car[['cty','hwy','cyl','displ']]
Matrix = car_new1.corr()
Matrix
# Out:
#             cty       hwy       cyl     displ
# cty    1.000000  0.955916 -0.805771 -0.798524
# hwy    0.955916  1.000000 -0.761912 -0.766020
# cyl   -0.805771 -0.761912  1.000000  0.930227
# displ -0.798524 -0.766020  0.930227  1.000000

# %%
plt.matshow(Matrix)
plt.show()

# %%
from pydataset import data

df = data("mtcars")

# %%
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
plt.rcParams["figure.figsize"]=14,8
matrix = df.corr()
plt.matshow(matrix,cmap="Blues")
plt.colorbar()
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)),df.columns)
plt.show()

# %%
import os

# %%
path=r"D:/EDA/New folder/IPL Data"
os.chdir(path)
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'ANOVA.ipynb',
#  'Ball_by_Ball.xlsx',
#  'Bivariate Analysis.ipynb',
#  'Call Centre Analysis- Data set.rar',
#  'Calling Data.xlsx',
#  'Calling_Data.ipynb',
#  'Cars.xlsx',
#  'Chi square test.ipynb',
#  'daily-minimum-temperatures.xlsx',
#  'Data and time.xlsx',
#  'Drinks.xlsx',
#  'Election data base.xlsb',
#  'Election data base.xlsx',
#  'Enrollment Data.xlsx',
#  'HR Analytics.csv',
#  'HR Analytics.docx',
#  'HR analytics.ipynb',
#  'ID Table.xlsx',
#  'IPL data analysis.ipynb',
#  'Leads.xlsx',
#  'Match.xlsx',
#  'narendramodi_tweets.xlsx',
#  'Player.xlsx',
#  'Player_Match.xlsx',
#  'Quiz-2.ipynb',
#  'Quiz1.ipynb',
#  'Season.xlsx',
#  'Students Marks.xlsx',
#  'Team.xlsx',
#  'tyre.csv',
#  'Univariate Analysis.ipynb',
#  'Untitled.ipynb']

# %%
import numpy as np
import pandas as pd

# %%
election=pd.read_excel('Election data base.xlsx')

# %%
election.head()
# Out:
#           st_name    year  ac_no    ac_name ac_type  \
# 0  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 1  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 2  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 3  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 4  Andhra Pradesh  1978.0      1  Ichapuram     GEN
#
#                    cand_name cand_sex                     partyname  \
# 0           Manabala Ramarao        M                   Independent
# 1                Appadu Sahu        M                   Independent
# 2           Uppada Rangababu        M      Indian National Congress
# 3       Kalla Balarama Swamy        M  Indian National Congress (I)
# 4  Bendalam Venkatesam Sarma        M                  Janata Party
#
#   partyabbre  totvotpoll  electors
# 0        IND       813.0     83247
# 1        IND      1743.0     83247
# 2        INC      4427.0     83247
# 3     INC(I)     19805.0     83247
# 4        JNP     34251.0     83247

# %%
Null_value=election.isnull().sum()

# %%
Null_value
# Out:
# st_name           0
# year              0
# ac_no             0
# ac_name       16083
# ac_type           0
# cand_name         1
# cand_sex       5302
# partyname         0
# partyabbre     2706
# totvotpoll        7
# electors          0
# dtype: int64

# %%
p=(Null_value/len(election.index))*100
p
# Out:
# st_name       0.000000
# year          0.000000
# ac_no         0.000000
# ac_name       4.913931
# ac_type       0.000000
# cand_name     0.000306
# cand_sex      1.619950
# partyname     0.000000
# partyabbre    0.826780
# totvotpoll    0.002139
# electors      0.000000
# dtype: float64

# %%
import seaborn as sns

# %%
sns.heatmap(election.isnull(),cbar=False)

# %%
#Fillling the missing values by 0 in totvotpoll

election['Fill_by_zero']=election['totvotpoll'].fillna(0)
Null_value=election.isnull().sum()
Null_value
# Out:
# st_name             0
# year                0
# ac_no               0
# ac_name         16083
# ac_type             0
# cand_name           1
# cand_sex         5302
# partyname           0
# partyabbre       2706
# totvotpoll          7
# electors            0
# Fill_by_zero        0
# dtype: int64

# %%
#ffill=forward fill=> copy value from previous cell
#bfill=backward fill=>copy value from next cell

# %%
election['FFill_by_zero']=election['totvotpoll'].fillna(method='ffill')
Null_value=election.isnull().sum()
Null_value
# Out:
# st_name              0
# year                 0
# ac_no                0
# ac_name          16083
# ac_type              0
# cand_name            1
# cand_sex          5302
# partyname            0
# partyabbre        2706
# totvotpoll           7
# electors             0
# Fill_by_zero         0
# FFill_by_zero        0
# dtype: int64

# %%
#filter for Sikkhim for year =2004

# %%
mean=election['totvotpoll'].mean()
mean
# Out:
# 9299.67342118691

# %%
election['fill_by_mean']=election['totvotpoll'].fillna(mean)

# %%
election['FFill_by_zero']=election['totvotpoll'].fillna(method='ffill')
Null_value=election.isnull().sum()
Null_value
# Out:
# st_name              0
# year                 0
# ac_no                0
# ac_name          16083
# ac_type              0
# cand_name            1
# cand_sex          5302
# partyname            0
# partyabbre        2706
# totvotpoll           7
# electors             0
# Fill_by_zero         0
# FFill_by_zero        0
# fill_by_mean         0
# dtype: int64

# %%
sik_data=election[election['st_name']=='Sikkim']
sik_data.head()
# Out:
#        st_name    year  ac_no ac_name ac_type              cand_name cand_sex  \
# 228351  Sikkim  1979.0      1  Yoksam     GEN          Mangal Limboo        M
# 228352  Sikkim  1979.0      1  Yoksam     GEN  Chewang Dorjee Bhutia        M
# 228353  Sikkim  1979.0      1  Yoksam     GEN     Ram Bahadur Limboo        M
# 228354  Sikkim  1979.0      1  Yoksam     GEN     Mohan Kumar Gurung        M
# 228355  Sikkim  1979.0      1  Yoksam     GEN      Ashok Kumar Subba        M
#
#                           partyname partyabbre  totvotpoll  electors  \
# 228351          Sikkim Congress (R)        SCR       143.0      3743
# 228352                 Independents        IND       153.0      3743
# 228353                  Janta Party        JNP       311.0      3743
# 228354  Sikkim Prajatantra Congress        SPC       468.0      3743
# 228355                 Independents        IND       556.0      3743
#
#         Fill_by_zero  FFill_by_zero  fill_by_mean
# ...

# %%
sik1=sik_data[sik_data['year']==2004]

# %%
sik1
# Out:
#        st_name    year  ac_no           ac_name ac_type  \
# 229199  Sikkim  2004.0      1            Yoksam     GEN
# 229200  Sikkim  2004.0      1            Yoksam     GEN
# 229201  Sikkim  2004.0      1            Yoksam     GEN
# 229202  Sikkim  2004.0      2         Tashiding      BL
# 229203  Sikkim  2004.0      2         Tashiding      BL
# 229204  Sikkim  2004.0      2         Tashiding      BL
# 229205  Sikkim  2004.0      3           Geyzing     GEN
# 229206  Sikkim  2004.0      3           Geyzing     GEN
# 229207  Sikkim  2004.0      3           Geyzing     GEN
# 229208  Sikkim  2004.0      3           Geyzing     GEN
# 229209  Sikkim  2004.0      4            Dentam     GEN
# 229210  Sikkim  2004.0      4            Dentam     GEN
# 229211  Sikkim  2004.0      4            Dentam     GEN
# 229212  Sikkim  2004.0      5           Barmiok     GEN
# 229213  Sikkim  2004.0      5           Barmiok     GEN
# 229214  Sikkim  2004.0      5           Barmiok     GEN
# ...
